# %%
# !pip list
# Out:
# Package                Version
# ---------------------- ---------
# absl-py                1.2.0
# arrow                  1.2.3
# astunparse             1.6.3
# binaryornot            0.4.4
# brotlipy               0.7.0
# cachetools             5.2.0
# certifi                2022.9.24
# cffi                   1.15.1
# charset-normalizer     2.1.1
# colorama               0.4.5
# conda                  4.13.0
# conda-package-handling 1.8.1
# contourpy              1.0.6
# cookiecutter           2.1.1
# cryptography           37.0.4
# cycler                 0.11.0
# flatbuffers            1.12
# fonttools              4.38.0
# gast                   0.4.0
# google-auth            2.10.0
# google-auth-oauthlib   0.4.6
# google-pasta           0.2.0
# idna                   3.4
# importlib-metadata     4.12.0
# Jinja2                 3.1.2
# jinja2-time            0.2.0
# keras                  2.9.0
# Keras-Preprocessing    1.1.2
# kiwisolver             1.4.4
# libclang               14.0.6
# Markdown               3.4.1
# MarkupSafe             2.1.1
# matplotlib             3.6.2
# neovim                 0.3.1
# numpy                  1.23.5
# oauthlib               3.2.0
# opencv-python          4.6.0.66
# opt-einsum             3.3.0
# packaging              21.3
# Pillow                 9.3.0
# pip                    22.2.2
# protobuf               3.19.4
# pyasn1                 0.4.8
# pyasn1-modules         0.2.8
# pycosat                0.6.3
# pycparser              2.21
# pyOpenSSL              22.0.0
# pyparsing              3.0.9
# PySocks                1.7.1
# python-dateutil        2.8.2
# python-rapidjson       1.9
# python-slugify         6.1.2
# requests               2.28.1
# requests-oauthlib      1.3.1
# rsa                    4.9
# ruamel-yaml-conda      0.15.80
# setuptools             64.0.3
# six                    1.16.0
# termcolor              1.1.0
# text-unidecode         1.3
# tqdm                   4.64.0
# tritonclient           2.28.0
# typing_extensions      4.3.0
# urllib3                1.26.12
# Werkzeug               2.2.2
# wheel                  0.37.1
# wrapt                  1.14.1
# zipp                   3.8.1

# %%
# !pip -V
# Out:
# pip 22.2.2 from /Users/zhangxin/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages/pip (python 3.9)

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# Requirement already satisfied: opencv-python in /Users/zhangxin/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.19.3 in /Users/zhangxin/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages (from opencv-python) (1.23.5)

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /Users/zhangxin/.pyenv/versions/miniforge3-4.10.3-10
# env_tensorflow           /Users/zhangxin/.pyenv/versions/miniforge3-4.10.3-10/envs/env_tensorflow
# ml                    *  /Users/zhangxin/.pyenv/versions/miniforge3-4.10.3-10/envs/ml
#
#
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
# !pip install matplotlib
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# Requirement already satisfied: matplotlib in /Users/zhangxin/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages (3.6.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/zhangxin/.local/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/zhangxin/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/zhangxin/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: numpy>=1.19 in /Users/zhangxin/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/zhangxin/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/zhangxin/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/zhangxin/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /Users/zhangxin/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/zhangxin/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: six>=1.5 in /Users/zhangxin/.pyenv/versions/miniforge3-4.10.3-10/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import numpy as np
import matplotlib.pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Fills and Alpha Example")
plt.show()
